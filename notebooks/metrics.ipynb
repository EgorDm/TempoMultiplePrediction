# %%
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = [20, 10]

# %%
import settings
from helpers import osu, visualization

# %%
db = osu.database.OsuDB(os.getenv('OSU_ROOT') + '\\osu!.db')
# Out:
# 20180811
# Reading egordm's database. Expecting 55837 maps.
# Loaded 55837/55837 maps.

# %%
ranked_entries = list(filter(lambda e: e.ranked >= 4, db.beatmaps))
len(ranked_entries)
# Out:
# 51133

# %%
visualization.sample_metrics.bpm_histogram(ranked_entries)
